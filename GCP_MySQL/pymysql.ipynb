# %%
import pymysql
import pandas as pd

# %%
conn = pymysql.connect(host= '35.221.199.83', port=3306, user='tele', passwd='tele', charset= 'utf8mb4')
cursor = conn.cursor()
cursor.execute('USE Telegonosis')
# Out:
# 0

# %%
pd.read_sql("SELECT * FROM Persons", conn, index_col='id')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10752\818713815.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM Persons", conn, index_col='id')
#                                         Title  \
# id
# 1                   國際貨幣基金組織：FED 應至少等到年底才開始降息
# 2                   歐盟新法逼近，蘋果開發 iPhone 新換電池技術
# 3                   H＆M銷售展望不妙、全年獲利難達標？股價崩 13%
# 4         AI 持續推動半導體需求，高盛預期台積電 2024 年業績展望維持不變
# 5                    散戶逆勢搶入？高盛：避險基金 6 月大賣半導體股
# ..                                        ...
# 103                              刚刚，李斌投出一个IPO
# 104                         去班味的水枪，滋出一个亿级玩具产业
# 105  美媒总结美国大选候选人电视辩论前30分钟双方表现：拜登时而语无伦次，特朗普撒了谎
# 106                              AI产品悄悄争夺超级入口
# 107                    500亿医药巨头，出手，医药的春天，要来了？
#
#                                   Trans_Title  \
# id
# 1
# 2
# 3
# 4
# 5
# ...
